# %%
# Filter columns with at least 30% non-null values
df2 = df[[column for column in df if df[column].count() / len(df) >= 0.3]]

# Delete the 'refer column' column from df2
del df2['Invoice ID']

print("List of dropped columns:", end=" ")
for c in df.columns:
    if c not in df2.columns:
        print(c, end="")
print('\n')
df = df2
